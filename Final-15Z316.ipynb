# %%
import pandas as pd
a=pd.read_csv("C:/Users/cse16/Desktop/Sapfile1.csv",error_bad_lines=False)
a.head()
# Out:
#   ge   cst   tnp   twp iap   esp arr         ms ls    as   ...     fq  mq  \
# 0  F     G  Good  Good  Vg  Good   Y  Unmarried  V  Paid   ...     Um  10
# 1  M   OBC    Vg    Vg  Vg    Vg   N  Unmarried  V  Paid   ...     Um  Il
# 2  F   OBC  Good  Good  Vg  Good   N  Unmarried  V  Paid   ...     12  10
# 3  M  MOBC  Pass  Good  Vg  Good   N  Unmarried  V  Paid   ...     12  Um
# 4  M     G  Good  Good  Vg    Vg   N  Unmarried  V  Paid   ...     10  12
#
#          fo         mo       nf       sh       ss   me       tt      atd
# 0    Farmer  Housewife    Large     Poor     Govt  Asm    Small     Good
# 1   Service    Service    Small     Poor     Govt  Asm  Average  Average
# 2   Service  Housewife  Average  Average     Govt  Asm    Large     Good
# 3  Business   Business    Large     Poor     Govt  Asm  Average  Average
# 4   Service  Housewife    Large     Poor  Private  Asm    Small     Good
#
# [5 rows x 22 columns]

# %%
a.describe()
# Out:
#          ge  cst   tnp   twp  iap   esp  arr         ms   ls    as  ...    fq  \
# count   131  131   131   131  131   131  131        131  131   131  ...   131
# unique    2    5     4     4    4     4    2          1    2     2  ...     6
# top       M  OBC  Good  Good   Vg  Good    N  Unmarried    V  Paid  ...    Um
# freq     72   57    59    65   63    54   78        131   92    76  ...    40
#
#          mq       fo         mo     nf       sh    ss   me     tt   atd
# count   131      131        131    131      131   131  131    131   131
# unique    6        5          5      3        3     2    4      3     3
# top      Um  Service  Housewife  Large  Average  Govt  Eng  Small  Good
# freq     52       38        115     58       59    91   62     78    56
#
# [4 rows x 22 columns]

# %%
df=pd.DataFrame(a)
list(df.columns)
# Out:
# ['ge',
#  'cst',
#  'tnp',
#  'twp',
#  'iap',
#  'esp',
#  'arr',
#  'ms',
#  'ls',
#  'as',
#  'fmi',
#  'fs',
#  'fq',
#  'mq',
#  'fo',
#  'mo',
#  'nf',
#  'sh',
#  'ss',
#  'me',
#  'tt',
#  'atd']

# %%
print(df)
# Out:
#     ge   cst   tnp   twp   iap   esp arr         ms ls    as   ...         fq  \
# 0    F     G  Good  Good    Vg  Good   Y  Unmarried  V  Paid   ...         Um
# 1    M   OBC    Vg    Vg    Vg    Vg   N  Unmarried  V  Paid   ...         Um
# 2    F   OBC  Good  Good    Vg  Good   N  Unmarried  V  Paid   ...         12
# 3    M  MOBC  Pass  Good    Vg  Good   N  Unmarried  V  Paid   ...         12
# 4    M     G  Good  Good    Vg    Vg   N  Unmarried  V  Paid   ...         10
# 5    M   OBC    Vg  Good    Vg    Vg   N  Unmarried  V  Paid   ...         10
# 6    F   OBC  Good    Vg  Good  Good   N  Unmarried  V  Paid   ...         12
# 7    F   OBC  Good  Good  Good  Good   N  Unmarried  V  Paid   ...         Il
# 8    F  MOBC    Vg  Good  Good    Vg   Y  Unmarried  V  Paid   ...         12
# 9    F   OBC    Vg    Vg  Good    Vg   Y  Unmarried  V  Paid   ...     Degree
# 10   M    ST    Vg    Vg  Good    Vg   N  Unmarried  V  Paid   ...         Pg
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 22 columns):
# ge     131 non-null object
# cst    131 non-null object
# tnp    131 non-null object
# twp    131 non-null object
# iap    131 non-null object
# esp    131 non-null object
# arr    131 non-null object
# ms     131 non-null object
# ls     131 non-null object
# as     131 non-null object
# fmi    131 non-null object
# fs     131 non-null object
# fq     131 non-null object
# mq     131 non-null object
# fo     131 non-null object
# mo     131 non-null object
# nf     131 non-null object
# sh     131 non-null object
# ss     131 non-null object
# me     131 non-null object
# tt     131 non-null object
# atd    131 non-null object
# dtypes: object(22)
# memory usage: 22.6+ KB

# %%
pd.isnull(df).any()
# Out:
# ge     False
# cst    False
# tnp    False
# twp    False
# iap    False
# esp    False
# arr    False
# ms     False
# ls     False
# as     False
# fmi    False
# fs     False
# fq     False
# mq     False
# fo     False
# mo     False
# nf     False
# sh     False
# ss     False
# me     False
# tt     False
# atd    False
# dtype: bool

# %%
x=df.groupby('ge')
x.head()
# Out:
#    ge   cst   tnp   twp   iap   esp arr         ms ls    as   ...     fq  \
# 0   F     G  Good  Good    Vg  Good   Y  Unmarried  V  Paid   ...     Um
# 1   M   OBC    Vg    Vg    Vg    Vg   N  Unmarried  V  Paid   ...     Um
# 2   F   OBC  Good  Good    Vg  Good   N  Unmarried  V  Paid   ...     12
# 3   M  MOBC  Pass  Good    Vg  Good   N  Unmarried  V  Paid   ...     12
# 4   M     G  Good  Good    Vg    Vg   N  Unmarried  V  Paid   ...     10
# 5   M   OBC    Vg  Good    Vg    Vg   N  Unmarried  V  Paid   ...     10
# 6   F   OBC  Good    Vg  Good  Good   N  Unmarried  V  Paid   ...     12
# 7   F   OBC  Good  Good  Good  Good   N  Unmarried  V  Paid   ...     Il
# 8   F  MOBC    Vg  Good  Good    Vg   Y  Unmarried  V  Paid   ...     12
# 10  M    ST    Vg    Vg  Good    Vg   N  Unmarried  V  Paid   ...     Pg
#
#         mq        fo         mo       nf       sh       ss   me       tt  \
# 0       10    Farmer  Housewife    Large     Poor     Govt  Asm    Small
# ...

# %%
a=pd.read_csv("C:/Users/cse16/Desktop/Sapfile1.csv",error_bad_lines=False)
a.head()
# Out:
#   ge   cst   tnp   twp iap   esp arr         ms ls    as  ...   mq        fo  \
# 0  F     G  Good  Good  Vg  Good   Y  Unmarried  V  Paid  ...   10    Farmer
# 1  M   OBC    Vg    Vg  Vg    Vg   N  Unmarried  V  Paid  ...   Il   Service
# 2  F   OBC  Good  Good  Vg  Good   N  Unmarried  V  Paid  ...   10   Service
# 3  M  MOBC  Pass  Good  Vg  Good   N  Unmarried  V  Paid  ...   Um  Business
# 4  M     G  Good  Good  Vg    Vg   N  Unmarried  V  Paid  ...   12   Service
#
#           mo       nf       sh       ss   me       tt      atd marks
# 0  Housewife    Large     Poor     Govt  Asm    Small     Good    98
# 1    Service    Small     Poor     Govt  Asm  Average  Average    96
# 2  Housewife  Average  Average     Govt  Asm    Large     Good    88
# 3   Business    Large     Poor     Govt  Asm  Average  Average    70
# 4  Housewife    Large     Poor  Private  Asm    Small     Good    90
#
# [5 rows x 23 columns]

# %%
df=pd.DataFrame(a)
df
# Out:
#     ge   cst   tnp   twp   iap   esp arr         ms ls    as  ...       mq  \
# 0    F     G  Good  Good    Vg  Good   Y  Unmarried  V  Paid  ...       10
# 1    M   OBC    Vg    Vg    Vg    Vg   N  Unmarried  V  Paid  ...       Il
# 2    F   OBC  Good  Good    Vg  Good   N  Unmarried  V  Paid  ...       10
# 3    M  MOBC  Pass  Good    Vg  Good   N  Unmarried  V  Paid  ...       Um
# 4    M     G  Good  Good    Vg    Vg   N  Unmarried  V  Paid  ...       12
# 5    M   OBC    Vg  Good    Vg    Vg   N  Unmarried  V  Paid  ...       Um
# 6    F   OBC  Good    Vg  Good  Good   N  Unmarried  V  Paid  ...   Degree
# 7    F   OBC  Good  Good  Good  Good   N  Unmarried  V  Paid  ...       Um
# 8    F  MOBC    Vg  Good  Good    Vg   Y  Unmarried  V  Paid  ...       10
# 9    F   OBC    Vg    Vg  Good    Vg   Y  Unmarried  V  Paid  ...   Degree
# 10   M    ST    Vg    Vg  Good    Vg   N  Unmarried  V  Paid  ...       Pg
# ...

# %%
df.boxplot(column='marks')

# %%
import pandas as pd
a=pd.read_csv("C:/Users/cse16/Desktop/Sapfile1.csv",error_bad_lines=False)

# %%
for i in a['ge']:
# Out:
# F
# M
# F
# M
# M
# M
# F
# F
# F
# F
# M
# F
# M
# M
# F
# F
# F
# M
# M
# M
# F
# F
# F
# F
# F
# F
# F
# F
# M
# F
# F
# F
# F
# M
# M
# F
# F
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# F
# M
# M
# F
# M
# F
# F
# F
# F
# F
# F
# F
# F
# F
# F
# F
# F
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# M
# F
# F
# F
# F
# F
# F
# F
# M
# M
# M
# F
# F
# F
# F
# F
# F
# F
# F
# M
# M
# M
# M
# M
# M
# M
# M
# F
# M
# M
# M
# M
# F
# F
# F
# M
# M
# M
# M
# F
# M
# M
# M
# M
# M
# M
# M
# F
# M
# M

# %%
import matplotlib
a['cst'].value_counts().plot.pie()

# %%
import matplotlib
a['cst'].value_counts().plot(kind='bar')
